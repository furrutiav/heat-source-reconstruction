# %% [markdown]
# Problema a tiempo directo
# \begin{align}
# -\partial_t \varphi - \gamma \Delta \varphi = v \chi_O, \quad \Omega,\\
# \varphi = 0, \quad \partial \Omega \times (0, \tau),\\
# \varphi(x, \tau) = \varphi_0, \quad \Omega,\\
# \varphi(x, 0) = 0, \quad \Omega
# \end{align}

# %% [markdown]
# Problema a tiempo inverso: $\Phi(x, t) = \varphi(x, \tau - t)$
# \begin{align}
# \partial_t \Phi - \gamma \Delta \Phi = v \chi_O, \quad \Omega,\\
# \Phi = 0, \quad \partial \Omega \times (0, \tau),\\
# \Phi(x, 0) = \varphi_0, \quad \Omega,\\
# || \Phi(x, \tau) || < \epsilon, \quad \Omega
# \end{align}

# %%
from dolfin import *
from dolfin_adjoint import *
import numpy as np
set_log_level(LogLevel.WARNING)
import pickle

# %%
mesh = UnitSquareMesh(32, 32)
V = FunctionSpace(mesh, "Lagrange", 1)
tol = 1e-14
# Defining bounday conditions

def boundary(x):
    return x[0] < DOLFIN_EPS or x[0] > 1.0 - DOLFIN_EPS or x[1] < DOLFIN_EPS or x[1] > 1.0 - DOLFIN_EPS
uD = Constant(0.0)
bc = DirichletBC(V, uD, boundary)

# %%
T = 0.5
dt = 0.01

# %%
tau = 0.1
eigenmode = 0

# %%
# Resolving the variational formulation    
phi0 = Function(V, f'../step_0/Eigen/eigenfunction_{eigenmode}.xml')
ind_O = interpolate(Expression('1/3 <= x[1] <= 2/3 ? 0.0 : 1.0', degree=4), V)

# u0 = interpolate(u0_opt, V)
u0 = interpolate(Expression("0.0", degree=4), V)
u = u0.copy(deepcopy=True)

phi_prev = phi0.copy(deepcopy=True) 
phi_next = phi0.copy(deepcopy=True) 

Tf = tau
t = 0.0
v = TestFunction(V)

states = [phi0.copy(deepcopy=True)]
controls = [v0.copy(deepcopy=True) ]
times = [float(t)]
timestep = 0

# %%
while abs(Tf-t)>=tol :
    print("Solving for t == %s" % (t + dt))

    F = inner((phi_next - phi_prev) / Constant(dt), v) * dx + inner(grad(phi_next), grad(v)) * dx - (u * ind_O) * v * dx
    solve(F == 0, phi_next, bc, annotate=True) # This is how dolfin-adjoint records the dependency of the control in each timestep
    
    phi_prev.assign(phi_next, annotate=True)
    
    t += dt
    timestep += 1
    
    states.append(phi_next.copy(deepcopy=True, annotate=True))

    times.append(float(t))
    print("Done!")
# Out:
# Solving for t == 0.005
# Done!
# Solving for t == 0.01
# Done!
# Solving for t == 0.015
# Done!
# Solving for t == 0.02
# Done!
# Solving for t == 0.025
# Done!
# Solving for t == 0.030000000000000002
# Done!
# Solving for t == 0.035
# Done!
# Solving for t == 0.04
# Done!
# Solving for t == 0.045
# Done!
# Solving for t == 0.049999999999999996
# Done!
# Solving for t == 0.05499999999999999
# Done!
# Solving for t == 0.05999999999999999
# Done!
# Solving for t == 0.06499999999999999
# Done!
# Solving for t == 0.06999999999999999
# Done!
# Solving for t == 0.075
# Done!
# Solving for t == 0.08
# Done!
# Solving for t == 0.085
# Done!
# Solving for t == 0.09000000000000001
# Done!
# Solving for t == 0.09500000000000001
# Done!
# Solving for t == 0.10000000000000002
# Done!

# %%
import matplotlib.pyplot as plt

# %%
t = -1
img = []
for i in range(100):
    row = []
    for j in range(100):
        row.append(states[t]([i/99,j/99]))
    img.append(row)
plt.imshow(img, vmin=0, vmax=2)
plt.title(t)
t+=5

# %%
len(states)
# Out:
# 21

# %%
# heat = File("heat.pvd")
# state = Function(V, name="state")
# for i in range(len(states)):
#     si = states[i]
#     state.vector().zero()
#     state.vector().axpy(1, si)
#     heat << state

# %%
# %%time
steps=len(times)
# and the minimizing problem
J = assemble(phi_next*phi_next*dx)
m = Control(u)#[Control(c) for c in controls]
RJ = ReducedFunctional(J,m)

u0_opt = minimize(RJ,tol=1.0e-10, options={"ftol": 1e-7})
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =         1089     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.29687D-02    |proj g|=  2.53443D-05
#
# At iterate    1    f=  1.52421D-02    |proj g|=  2.06459D-05
#
# At iterate    2    f=  2.32571D-09    |proj g|=  2.35367D-09
# CPU times: user 10.3 s, sys: 375 ms, total: 10.6 s
# At iterate    3    f=  8.70656D-10    |proj g|=  1.39779D-09
#
# Wall time: 10.7 s
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#  1089      3      7      1     0     0   1.398D-09   8.707D-10
#   F =   8.7065583716056332E-010
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH

# %%
u0_opt([2/3, 2/3])
# Out:
# -5.304467748323003

# %%
u0_opt.rename('u','u')

u0 = interpolate(u0_opt, V)
u = u0.copy(deepcopy=True)

phi_prev = phi0.copy(deepcopy=True) 
phi_next = phi0.copy(deepcopy=True) 

Tf = tau
t = 0.0
v = TestFunction(V)

states = [phi0.copy(deepcopy=True)]
controls = [u0.copy(deepcopy=True) ]
times = [float(t)]
timestep = 0
file = File(f'NullControls/Eigen_{eigenmode}_tau_{int(tau/dt)}/sol.pvd')
states[-1].rename('phi','phi')
file << (states[-1], 0)
while abs(Tf-t)>=tol :
    print("Solving for t == %s" % (t + dt))
    
    F = inner((phi_next - phi_prev) / Constant(dt), v) * dx + inner(grad(phi_next), grad(v)) * dx - (u * ind_O) * v * dx
    solve(F == 0, phi_next, bc, annotate=True) # This is how dolfin-adjoint records the dependency of the control in each timestep
    
    phi_prev.assign(phi_next, annotate=True)
    
    t += dt
    timestep += 1
    
    states.append(phi_next.copy(deepcopy=True, annotate=True))
    
    times.append(float(t))
    states[-1].rename('phi','phi')
    
    file << (states[-1],t)
    
    print("Done!")
# Out:
# Solving for t == 0.005
# Done!
# Solving for t == 0.01
# Done!
# Solving for t == 0.015
# Done!
# Solving for t == 0.02
# Done!
# Solving for t == 0.025
# Done!
# Solving for t == 0.030000000000000002
# Done!
# Solving for t == 0.035
# Done!
# Solving for t == 0.04
# Done!
# Solving for t == 0.045
# Done!
# Solving for t == 0.049999999999999996
# Done!
# Solving for t == 0.05499999999999999
# Done!
# Solving for t == 0.05999999999999999
# Done!
# Solving for t == 0.06499999999999999
# Done!
# Solving for t == 0.06999999999999999
# Done!
# Solving for t == 0.075
# Done!
# Solving for t == 0.08
# Done!
# Solving for t == 0.085
# Done!
# Solving for t == 0.09000000000000001
# Done!
# Solving for t == 0.09500000000000001
# Done!
# Solving for t == 0.10000000000000002
# Done!

# %%
t = -1
img = []
for i in range(100):
    row = []
    for j in range(100):
        row.append(states[t]([i/99,j/99]))
    img.append(row)
plt.imshow(img, vmin=-2, vmax=2)
plt.title(t)
t+=1

# %%
t = 1
img = []
for i in range(100):
    row = []
    for j in range(100):
        row.append(u0_opt([i/99,j/99]))
    img.append(row)
plt.imshow(img)
plt.title(t);

# %%
# %%time
dim = V.dim()
N = mesh.geometry().dim()
coor = V.tabulate_dof_coordinates().reshape(dim,N)

x = coor[:, 0]
y = coor[:, 1]

pickle.dump(
    {
        "control": u0_opt.vector()[:],
        "x": x, 
        "y": y
    },
    open(f"NullControls/Eigen_{eigenmode}_tau_{int(tau/dt)}/control.pickle", "wb")
)
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 3.01 ms

# %%
f_x, f_y = x[f_dofs], y[f_dofs]
f_x, f_y
# Out:
# (array([0.     , 0.     , 0.03125, ..., 0.96875, 1.     , 1.     ]),
#  array([1.     , 0.96875, 1.     , ..., 0.     , 0.03125, 0.     ]))

# %%
plt.scatter(f_x, f_y)

# %%
fe = Function(V)

# %%
fe.vector()[f_dofs] = np.sin(np.pi*f_x*2) + 5*f_y

# %%
plt.scatter(f_x, f_y, c=u0_opt.vector()[f_dofs])

# %% [markdown]
# # u0_opt.vector().array()
# https://fenicsproject.org/qa/3975/interpolating-vector-function-from-python-code-to-fenics/

# %%
T/dt
# Out:
# 100.0

# %%
from time import time

# %%
# %%time

mesh = UnitSquareMesh(32, 32)
V = FunctionSpace(mesh, "Lagrange", 1)
tol = 1e-14
# Defining bounday conditions

def boundary(x):
    return x[0] < DOLFIN_EPS or x[0] > 1.0 - DOLFIN_EPS or x[1] < DOLFIN_EPS or x[1] > 1.0 - DOLFIN_EPS
uD = Constant(0.0)
bc = DirichletBC(V, uD, boundary)

# Set params
T = 0.5
dt = 0.01

times_ = []
for eigenmode in range(4, 45):
    for ix in range(1, int(T/dt)+1):
        tau = dt * ix
        
        start = time()
        
        # Set intial conditions
        
        phi0 = Function(V, f'../step_0/Eigen/eigenfunction_{eigenmode}.xml')
        ind_O = interpolate(Expression('1/3 <= x[1] <= 2/3 ? 0.0 : 1.0', degree=4), V)

        u0 = interpolate(Expression("0.0", degree=4), V)
        u = u0.copy(deepcopy=True)

        phi_prev = phi0.copy(deepcopy=True) 
        phi_next = phi0.copy(deepcopy=True) 

        Tf = tau
        t = 0.0
        v = TestFunction(V)

        states = [phi0.copy(deepcopy=True)]
        controls = [u0.copy(deepcopy=True) ]
        times = [float(t)]
        timestep = 0
        
        # Set dynamic
        
        while abs(Tf-t)>=tol :
            print("Solving for t == %s" % (t + dt))

            F = inner((phi_next - phi_prev) / Constant(dt), v) * dx + inner(grad(phi_next), grad(v)) * dx - (u * ind_O) * v * dx
            solve(F == 0, phi_next, bc, annotate=True) # This is how dolfin-adjoint records the dependency of the control in each timestep

            phi_prev.assign(phi_next, annotate=True)

            t += dt
            timestep += 1

            states.append(phi_next.copy(deepcopy=True, annotate=True))

            times.append(float(t))
            print("[Set dynamic] Done!")
        
        # Optimize

        print("Optimize...")
        steps=len(times)
        # and the minimizing problem
        J = assemble(phi_next*phi_next*dx)
        m = Control(u)
        RJ = ReducedFunctional(J,m)

        u0_opt = minimize(RJ,tol=1.0e-10, options={"ftol": 1e-7})
        print("Done!")
        
        # Get states
        u0_opt.rename('u','u')

        u0 = interpolate(u0_opt, V)
        u = u0.copy(deepcopy=True)

        phi_prev = phi0.copy(deepcopy=True) 
        phi_next = phi0.copy(deepcopy=True) 

        Tf = tau
        t = 0.0
        v = TestFunction(V)

        states = [phi0.copy(deepcopy=True)]
        controls = [u0.copy(deepcopy=True) ]
        times = [float(t)]
        timestep = 0
        file = File(f'NullControls/Eigen_{eigenmode}_tau_{ix}/sol.pvd')
        states[-1].rename('phi','phi')
        file << (states[-1], 0)
        while abs(Tf-t)>=tol :
            print("Solving for t == %s" % (t + dt))

            F = inner((phi_next - phi_prev) / Constant(dt), v) * dx + inner(grad(phi_next), grad(v)) * dx - (u * ind_O) * v * dx
            solve(F == 0, phi_next, bc, annotate=True) # This is how dolfin-adjoint records the dependency of the control in each timestep

            phi_prev.assign(phi_next, annotate=True)

            t += dt
            timestep += 1

            states.append(phi_next.copy(deepcopy=True, annotate=True))

            times.append(float(t))
            states[-1].rename('phi','phi')

            file << (states[-1],t)

            print("[Save states] Done!")
        
        # Get control
        dim = V.dim()
        N = mesh.geometry().dim()
        coor = V.tabulate_dof_coordinates().reshape(dim,N)

        x = coor[:, 0]
        y = coor[:, 1]

        pickle.dump(
            {
                "control": u0_opt.vector()[:],
                "x": x, 
                "y": y
            },
            open(f"NullControls/Eigen_{eigenmode}_tau_{ix}/control.pickle", "wb")
        )
        end = time()
        times_.append({"eigenmode": eigenmode, "tau": ix, "dt": end-start})
        
        pickle.dump(times_, open("times.pickle", "wb"))
# Out:
# Solving for t == 0.01
# [Set dynamic] Done!
# Optimize...
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =         1089     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.96919D-01    |proj g|=  2.71797D-05
#
# Done!
# At iterate    1    f=  5.56510D-01    |proj g|=  2.42881D-05
#
# At iterate    2    f=  1.79930D-07    |proj g|=  8.78955D-09
#
# At iterate    3    f=  8.10504D-08    |proj g|=  5.66562D-09
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#  1089      3      8      1     0     0   5.666D-09   8.105D-08
#   F =   8.1050413160086425E-008
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Solving for t == 0.01
# [Save states] Done!
# Solving for t == 0.01
# [Set dynamic] Done!
# Solving for t == 0.02
# [Set dynamic] Done!
# Optimize...
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =         1089     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.85696D-01    |proj g|=  4.16322D-05
#
# At iterate    1    f=  2.85102D-01    |proj g|=  3.18971D-05
#
# At iterate    2    f=  1.15544D-07    |proj g|=  1.11655D-08
# Done!
# Solving for t == 0.01
#
# At iterate    3    f=  6.21814D-08    |proj g|=  8.03283D-09
# [Save states] Done!
# Solving for t == 0.02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#  1089      3      8      1     0     0   8.033D-09   6.218D-08
#   F =   6.2181409726187598E-008
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# [Save states] Done!
# Solving for t == 0.01
# [Set dynamic] Done!
# Solving for t == 0.02
# [Set dynamic] Done!
# Solving for t == 0.03
# [Set dynamic] Done!
# Optimize...
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =         1089     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.38490D-01    |proj g|=  4.79563D-05
#
# At iterate    1    f=  1.27398D-01    |proj g|=  2.94213D-05
#
# At iterate    2    f=  7.11311D-08    |proj g|=  1.06692D-08
# Done!
# Solving for t == 0.01
# [Save states] Done!
# Solving for t == 0.02
#
# At iterate    3    f=  4.42476D-08    |proj g|=  8.21618D-09
#
#            * * *
#
# Tit   = total number of iterations
# [Save states] Done!
# Solving for t == 0.03
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#  1089      3      8      1     0     0   8.216D-09   4.425D-08
#   F =   4.4247615180409157E-008
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# [Save states] Done!
# Solving for t == 0.01
# [Set dynamic] Done!
# Solving for t == 0.02
# [Set dynamic] Done!
# Solving for t == 0.03
# [Set dynamic] Done!
# Solving for t == 0.04
# [Set dynamic] Done!
# Optimize...
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =         1089     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.35900D-01    |proj g|=  4.92348D-05
#
# At iterate    1    f=  1.73691D-01    |proj g|=  4.22472D-05
#
# At iterate    2    f=  4.32826D-08    |proj g|=  9.15284D-09
# Done!
#
# At iterate    3    f=  2.97682D-08    |proj g|=  7.49517D-09
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#  1089      3      7      1     0     0   7.495D-09   2.977D-08
#   F =   2.9768188373881193E-008
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Solving for t == 0.01
# [Save states] Done!
# Solving for t == 0.02
# [Save states] Done!
# Solving for t == 0.03
# [Save states] Done!
# Solving for t == 0.04
# [Save states] Done!
# Solving for t == 0.01
# [Set dynamic] Done!
# Solving for t == 0.02
# [Set dynamic] Done!
# Solving for t == 0.03
# [Set dynamic] Done!
# Solving for t == 0.04
# [Set dynamic] Done!
# Solving for t == 0.05
# [Set dynamic] Done!
# Optimize...
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =         1089     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.64403D-01    |proj g|=  4.75138D-05
#
# At iterate    1    f=  1.06132D-01    |proj g|=  3.81759D-05
#
# At iterate    2    f=  2.64794D-08    |proj g|=  7.51375D-09
# Done!
#
# Solving for t == 0.01
# [Save states] Done!
# Solving for t == 0.02
# [Save states] Done!
# Solving for t == 0.03
# [Save states] Done!
# Solving for t == 0.04
# At iterate    3    f=  1.95025D-08    |proj g|=  6.39775D-09
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#  1089      3      7      1     0     0   6.398D-09   1.950D-08
#   F =   1.9502534815851338E-008
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# [Save states] Done!
# Solving for t == 0.05
# [Save states] Done!
# Solving for t == 0.01
# [Set dynamic] Done!
# Solving for t == 0.02
# [Set dynamic] Done!
# Solving for t == 0.03
# [Set dynamic] Done!
# Solving for t == 0.04
# [Set dynamic] Done!
# Solving for t == 0.05
# [Set dynamic] Done!
# Solving for t == 0.060000000000000005
# [Set dynamic] Done!
# Optimize...
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =         1089     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.14576D-01    |proj g|=  4.41337D-05
#
# At iterate    1    f=  6.24132D-02    |proj g|=  3.25735D-05
#
# At iterate    2    f=  1.64094D-08    |proj g|=  6.06846D-09
# Done!
#
# At iterate    3    f=  1.26728D-08    |proj g|=  5.30355D-09
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Solving for t == 0.01
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#  1089      3      7      1     0     0   5.304D-09   1.267D-08
#   F =   1.2672824205865313E-008
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# [Save states] Done!
# Solving for t == 0.02
# [Save states] Done!
# Solving for t == 0.03
# [Save states] Done!
# Solving for t == 0.04
# [Save states] Done!
# Solving for t == 0.05
# [Save states] Done!
# Solving for t == 0.060000000000000005
# [Save states] Done!
# Solving for t == 0.01
# [Set dynamic] Done!
# Solving for t == 0.02
# [Set dynamic] Done!
# Solving for t == 0.03
# [Set dynamic] Done!
# Solving for t == 0.04
# [Set dynamic] Done!
# Solving for t == 0.05
# [Set dynamic] Done!
# Solving for t == 0.060000000000000005
# [Set dynamic] Done!
# Solving for t == 0.07
# [Set dynamic] Done!
# Optimize...
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =         1089     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.98500D-02    |proj g|=  3.99577D-05
#
# At iterate    1    f=  3.47521D-02    |proj g|=  2.63606D-05
#
# At iterate    2    f=  1.03252D-08    |proj g|=  4.88105D-09
# Done!
#
# Solving for t == 0.01
# At iterate    3    f=  8.24628D-09    |proj g|=  4.34365D-09
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#  1089      3      7      1     0     0   4.344D-09   8.246D-09
#   F =   8.2462765677047070E-009
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# [Save states] Done!
# Solving for t == 0.02
# [Save states] Done!
# Solving for t == 0.03
# [Save states] Done!
# Solving for t == 0.04
# [Save states] Done!
# Solving for t == 0.05
# [Save states] Done!
# Solving for t == 0.060000000000000005
# [Save states] Done!
# Solving for t == 0.07
# [Save states] Done!
# Solving for t == 0.01
# [Set dynamic] Done!
# Solving for t == 0.02
# [Set dynamic] Done!
# Solving for t == 0.03
# [Set dynamic] Done!
# Solving for t == 0.04
# [Set dynamic] Done!
# Solving for t == 0.05
# [Set dynamic] Done!
# Solving for t == 0.060000000000000005
# [Set dynamic] Done!
# Solving for t == 0.07
# [Set dynamic] Done!
# Solving for t == 0.08
# [Set dynamic] Done!
# Optimize...
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =         1089     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.56490D-02    |proj g|=  3.55276D-05
#
# At iterate    1    f=  4.43515D-02    |proj g|=  3.17170D-05
#
# At iterate    2    f=  6.59543D-09    |proj g|=  3.93101D-09
# Done!
#
# Solving for t == 0.01
# At iterate    3    f=  5.39709D-09    |proj g|=  3.54365D-09
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#  1089      3      6      1     0     0   3.544D-09   5.397D-09
#   F =   5.3970864548471234E-009
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# [Save states] Done!
# Solving for t == 0.02
# [Save states] Done!
# Solving for t == 0.03
# [Save states] Done!
# Solving for t == 0.04
# [Save states] Done!
# Solving for t == 0.05
# [Save states] Done!
# Solving for t == 0.060000000000000005
# [Save states] Done!
# Solving for t == 0.07
# [Save states] Done!
# Solving for t == 0.08
# [Save states] Done!
# Solving for t == 0.01
# [Set dynamic] Done!
# Solving for t == 0.02
# [Set dynamic] Done!
# Solving for t == 0.03
# [Set dynamic] Done!
# Solving for t == 0.04
# [Set dynamic] Done!
# Solving for t == 0.05
# [Set dynamic] Done!
# Solving for t == 0.060000000000000005
# [Set dynamic] Done!
# Solving for t == 0.07
# [Set dynamic] Done!
# Solving for t == 0.08
# [Set dynamic] Done!
# Solving for t == 0.09
# [Set dynamic] Done!
# Optimize...
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =         1089     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.87828D-02    |proj g|=  3.11716D-05
#
# At iterate    1    f=  2.90160D-02    |proj g|=  2.69624D-05
#
# At iterate    2    f=  4.27132D-09    |proj g|=  3.17693D-09
# Done!
#
# At iterate    3    f=  1.39978D-09    |proj g|=  1.74808D-09
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#  1089      3      7      1     0     0   1.748D-09   1.400D-09
#   F =   1.3997753158790047E-009
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Solving for t == 0.01
# [Save states] Done!
# Solving for t == 0.02
# [Save states] Done!
# Solving for t == 0.03
# [Save states] Done!
# Solving for t == 0.04
# [Save states] Done!
# Solving for t == 0.05
# [Save states] Done!
# Solving for t == 0.060000000000000005
# [Save states] Done!
# Solving for t == 0.07
# [Save states] Done!
# Solving for t == 0.08
# [Save states] Done!
# Solving for t == 0.09
# [Save states] Done!
# Solving for t == 0.01
# [Set dynamic] Done!
# Solving for t == 0.02
# [Set dynamic] Done!
# Solving for t == 0.03
# [Set dynamic] Done!
# Solving for t == 0.04
# [Set dynamic] Done!
# Solving for t == 0.05
# [Set dynamic] Done!
# Solving for t == 0.060000000000000005
# [Set dynamic] Done!
# Solving for t == 0.07
# [Set dynamic] Done!
# Solving for t == 0.08
# [Set dynamic] Done!
# Solving for t == 0.09
# [Set dynamic] Done!
# Solving for t == 0.09999999999999999
# [Set dynamic] Done!
# Optimize...
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =         1089     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.70285D-02    |proj g|=  2.70767D-05
#
# At iterate    1    f=  1.86960D-02    |proj g|=  2.25196D-05
#
# At iterate    2    f=  2.79968D-09    |proj g|=  2.57819D-09
# Done!
# At iterate    3    f=  1.01356D-09    |proj g|=  1.50219D-09
#
# Solving for t == 0.01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#  1089      3      7      1     0     0   1.502D-09   1.014D-09
#   F =   1.0135604541586182E-009
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# [Save states] Done!
# Solving for t == 0.02
# [Save states] Done!
# Solving for t == 0.03
# [Save states] Done!
# Solving for t == 0.04
# [Save states] Done!
# Solving for t == 0.05
# [Save states] Done!
# Solving for t == 0.060000000000000005
# [Save states] Done!
# Solving for t == 0.07
# [Save states] Done!
# Solving for t == 0.08
# [Save states] Done!
# Solving for t == 0.09
# [Save states] Done!
# Solving for t == 0.09999999999999999
# [Save states] Done!
# Solving for t == 0.01
# [Set dynamic] Done!
# Solving for t == 0.02
# [Set dynamic] Done!
# Solving for t == 0.03
# [Set dynamic] Done!
# Solving for t == 0.04
# [Set dynamic] Done!
# Solving for t == 0.05
# [Set dynamic] Done!
# Solving for t == 0.060000000000000005
# [Set dynamic] Done!
# Solving for t == 0.07
# [Set dynamic] Done!
# Solving for t == 0.08
# [Set dynamic] Done!
# Solving for t == 0.09
# [Set dynamic] Done!
# Solving for t == 0.09999999999999999
# [Set dynamic] Done!
# Solving for t == 0.10999999999999999
# [Set dynamic] Done!
# Optimize...
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =         1089     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.88366D-02    |proj g|=  2.33387D-05
#
# At iterate    1    f=  1.18108D-02    |proj g|=  1.84805D-05
#
# At iterate    2    f=  1.85404D-09    |proj g|=  2.10090D-09
# Done!
#
# At iterate    3    f=  7.22765D-10    |proj g|=  1.27631D-09
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#  1089      3      7      1     0     0   1.276D-09   7.228D-10
#   F =   7.2276459250634089E-010
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Solving for t == 0.01
# [Save states] Done!
# Solving for t == 0.02
# [Save states] Done!
# Solving for t == 0.03
# [Save states] Done!
# Solving for t == 0.04
# [Save states] Done!
# Solving for t == 0.05
# [Save states] Done!
# Solving for t == 0.060000000000000005
# [Save states] Done!
# Solving for t == 0.07
# [Save states] Done!
# Solving for t == 0.08
# [Save states] Done!
# Solving for t == 0.09
# [Save states] Done!
# Solving for t == 0.09999999999999999
# [Save states] Done!
# Solving for t == 0.10999999999999999
# [Save states] Done!
# Solving for t == 0.01
# [Set dynamic] Done!
# Solving for t == 0.02
# [Set dynamic] Done!
# Solving for t == 0.03
# [Set dynamic] Done!
# Solving for t == 0.04
# [Set dynamic] Done!
# Solving for t == 0.05
# [Set dynamic] Done!
# Solving for t == 0.060000000000000005
# [Set dynamic] Done!
# Solving for t == 0.07
# [Set dynamic] Done!
# Solving for t == 0.08
# [Set dynamic] Done!
# Solving for t == 0.09
# [Set dynamic] Done!
# Solving for t == 0.09999999999999999
# [Set dynamic] Done!
# Solving for t == 0.10999999999999999
# [Set dynamic] Done!
# Solving for t == 0.11999999999999998
# [Set dynamic] Done!
# Optimize...
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =         1089     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.31276D-02    |proj g|=  1.99955D-05
#
# At iterate    1    f=  7.26855D-03    |proj g|=  1.48787D-05
#
# At iterate    2    f=  1.23848D-09    |proj g|=  1.71841D-09
# Done!
#
# Solving for t == 0.01
# At iterate    3    f=  5.10661D-10    |proj g|=  1.07712D-09
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#  1089      3      7      1     0     0   1.077D-09   5.107D-10
#   F =   5.1066102396860472E-010
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# [Save states] Done!
# Solving for t == 0.02
# [Save states] Done!
# Solving for t == 0.03
# [Save states] Done!
# Solving for t == 0.04
# [Save states] Done!
# Solving for t == 0.05
# [Save states] Done!
# Solving for t == 0.060000000000000005
# [Save states] Done!
# Solving for t == 0.07
# [Save states] Done!
# Solving for t == 0.08
# [Save states] Done!
# Solving for t == 0.09
# [Save states] Done!
# Solving for t == 0.09999999999999999
# [Save states] Done!
# Solving for t == 0.10999999999999999
# [Save states] Done!
# Solving for t == 0.11999999999999998
# [Save states] Done!
# Solving for t == 0.01
# [Set dynamic] Done!
# Solving for t == 0.02
# [Set dynamic] Done!
# Solving for t == 0.03
# [Set dynamic] Done!
# Solving for t == 0.04
# [Set dynamic] Done!
# Solving for t == 0.05
# [Set dynamic] Done!
# Solving for t == 0.060000000000000005
# [Set dynamic] Done!
# Solving for t == 0.07
# [Set dynamic] Done!
# Solving for t == 0.08
# [Set dynamic] Done!
# Solving for t == 0.09
# [Set dynamic] Done!
# Solving for t == 0.09999999999999999
# [Set dynamic] Done!
# Solving for t == 0.10999999999999999
# [Set dynamic] Done!
# Solving for t == 0.11999999999999998
# [Set dynamic] Done!
# Solving for t == 0.12999999999999998
# [Set dynamic] Done!
# Optimize...
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =         1089     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.14887D-03    |proj g|=  1.70494D-05
#
# At iterate    1    f=  4.31690D-03    |proj g|=  1.17115D-05
#
# At iterate    2    f=  8.33286D-10    |proj g|=  1.41019D-09
# Done!
# Solving for t == 0.01
#
# At iterate    3    f=  3.58776D-10    |proj g|=  9.05324D-10
#
# [Save states] Done!
# Solving for t == 0.02
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#  1089      3      7      1     0     0   9.053D-10   3.588D-10
#   F =   3.5877567509180567E-010
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# [Save states] Done!
# Solving for t == 0.03
# [Save states] Done!
# Solving for t == 0.04
# [Save states] Done!
# Solving for t == 0.05
# [Save states] Done!
# Solving for t == 0.060000000000000005
# [Save states] Done!
# Solving for t == 0.07
# [Save states] Done!
# Solving for t == 0.08
# [Save states] Done!
# Solving for t == 0.09
# [Save states] Done!
# Solving for t == 0.09999999999999999
# [Save states] Done!
# Solving for t == 0.10999999999999999
# [Save states] Done!
# Solving for t == 0.11999999999999998
# [Save states] Done!
# Solving for t == 0.12999999999999998
# [Save states] Done!
# Solving for t == 0.01
# [Set dynamic] Done!
# Solving for t == 0.02
# [Set dynamic] Done!
# Solving for t == 0.03
# [Set dynamic] Done!
# Solving for t == 0.04
# [Set dynamic] Done!
# Solving for t == 0.05
# [Set dynamic] Done!
# Solving for t == 0.060000000000000005
# [Set dynamic] Done!
# Solving for t == 0.07
# [Set dynamic] Done!
# Solving for t == 0.08
# [Set dynamic] Done!
# Solving for t == 0.09
# [Set dynamic] Done!
# Solving for t == 0.09999999999999999
# [Set dynamic] Done!
# Solving for t == 0.10999999999999999
# [Set dynamic] Done!
# Solving for t == 0.11999999999999998
# [Set dynamic] Done!
# Solving for t == 0.12999999999999998
# [Set dynamic] Done!
# Solving for t == 0.13999999999999999
# [Set dynamic] Done!
# Optimize...
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =         1089     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.37602D-03    |proj g|=  1.44818D-05
#
# At iterate    1    f=  2.43840D-03    |proj g|=  8.95572D-06
#
# At iterate    2    f=  5.64035D-10    |proj g|=  1.16051D-09
# Done!
# At iterate    3    f=  2.51197D-10    |proj g|=  7.59018D-10
#
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#  1089      3      7      1     0     0   7.590D-10   2.512D-10
#   F =   2.5119698228005073E-010
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Solving for t == 0.01
# [Save states] Done!
# Solving for t == 0.02
# [Save states] Done!
# Solving for t == 0.03
# [Save states] Done!
# Solving for t == 0.04
# [Save states] Done!
# Solving for t == 0.05
# [Save states] Done!
# Solving for t == 0.060000000000000005
# [Save states] Done!
# Solving for t == 0.07
# [Save states] Done!
# Solving for t == 0.08
# [Save states] Done!
# Solving for t == 0.09
# [Save states] Done!
# Solving for t == 0.09999999999999999
# [Save states] Done!
# Solving for t == 0.10999999999999999
# [Save states] Done!
# Solving for t == 0.11999999999999998
# [Save states] Done!
# Solving for t == 0.12999999999999998
# [Save states] Done!
# Solving for t == 0.13999999999999999
# [Save states] Done!
# Solving for t == 0.01
# [Set dynamic] Done!
# Solving for t == 0.02
# [Set dynamic] Done!
# Solving for t == 0.03
# [Set dynamic] Done!
# Solving for t == 0.04
# [Set dynamic] Done!
# Solving for t == 0.05
# [Set dynamic] Done!
# Solving for t == 0.060000000000000005
# [Set dynamic] Done!
# Solving for t == 0.07
# [Set dynamic] Done!
# Solving for t == 0.08
# [Set dynamic] Done!
# Solving for t == 0.09
# [Set dynamic] Done!
# Solving for t == 0.09999999999999999
# [Set dynamic] Done!
# Solving for t == 0.10999999999999999
# [Set dynamic] Done!
# Solving for t == 0.11999999999999998
# [Set dynamic] Done!
# Solving for t == 0.12999999999999998
# [Set dynamic] Done!
# Solving for t == 0.13999999999999999
# [Set dynamic] Done!
# Solving for t == 0.15
# [Set dynamic] Done!
# Optimize...
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =         1089     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.44357D-03    |proj g|=  1.22629D-05
#
# At iterate    1    f=  3.51665D-03    |proj g|=  1.09092D-05
#
# At iterate    2    f=  3.83688D-10    |proj g|=  9.57319D-10
# Done!
# Solving for t == 0.01
# [Save states] Done!
# Solving for t == 0.02
#
# [Save states] Done!
# Solving for t == 0.03
# At iterate    3    f=  1.75504D-10    |proj g|=  6.35260D-10
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#  1089      3      6      1     0     0   6.353D-10   1.755D-10
#   F =   1.7550405470416688E-010
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# [Save states] Done!
# Solving for t == 0.04
# [Save states] Done!
# Solving for t == 0.05
# [Save states] Done!
# Solving for t == 0.060000000000000005
# [Save states] Done!
# Solving for t == 0.07
# [Save states] Done!
# Solving for t == 0.08
# [Save states] Done!
# Solving for t == 0.09
# [Save states] Done!
# Solving for t == 0.09999999999999999
# [Save states] Done!
# Solving for t == 0.10999999999999999
# [Save states] Done!
# Solving for t == 0.11999999999999998
# [Save states] Done!
# Solving for t == 0.12999999999999998
# [Save states] Done!
# Solving for t == 0.13999999999999999
# [Save states] Done!
# Solving for t == 0.15
# [Save states] Done!
# Solving for t == 0.01
# [Set dynamic] Done!
# Solving for t == 0.02
# [Set dynamic] Done!
# Solving for t == 0.03
# [Set dynamic] Done!
# Solving for t == 0.04
# [Set dynamic] Done!
# Solving for t == 0.05
# [Set dynamic] Done!
# Solving for t == 0.060000000000000005
# [Set dynamic] Done!
# Solving for t == 0.07
# [Set dynamic] Done!
# Solving for t == 0.08
# [Set dynamic] Done!
# Solving for t == 0.09
# [Set dynamic] Done!
# Solving for t == 0.09999999999999999
# [Set dynamic] Done!
# Solving for t == 0.10999999999999999
# [Set dynamic] Done!
# Solving for t == 0.11999999999999998
# [Set dynamic] Done!
# Solving for t == 0.12999999999999998
# [Set dynamic] Done!
# Solving for t == 0.13999999999999999
# [Set dynamic] Done!
# Solving for t == 0.15
# [Set dynamic] Done!
# Solving for t == 0.16
# [Set dynamic] Done!
# Optimize...
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =         1089     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.09681D-03    |proj g|=  1.03581D-05
#
# At iterate    1    f=  2.32357D-03    |proj g|=  8.97221D-06
#
# At iterate    2    f=  2.62082D-10    |proj g|=  7.91282D-10
# Done!
# At iterate    3    f=  1.22462D-10    |proj g|=  5.31214D-10
#
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#  1089      3      6      1     0     0   5.312D-10   1.225D-10
#   F =   1.2246171810797993E-010
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Solving for t == 0.01
# [Save states] Done!
# Solving for t == 0.02
# [Save states] Done!
# Solving for t == 0.03
# [Save states] Done!
# Solving for t == 0.04
# [Save states] Done!
# Solving for t == 0.05
# [Save states] Done!
# Solving for t == 0.060000000000000005
# [Save states] Done!
# Solving for t == 0.07
# [Save states] Done!
# Solving for t == 0.08
# [Save states] Done!
# Solving for t == 0.09
# [Save states] Done!
# Solving for t == 0.09999999999999999
# [Save states] Done!
# Solving for t == 0.10999999999999999
# [Save states] Done!
# Solving for t == 0.11999999999999998
# [Save states] Done!
# Solving for t == 0.12999999999999998
# [Save states] Done!
# Solving for t == 0.13999999999999999
# [Save states] Done!
# Solving for t == 0.15
# [Save states] Done!
# Solving for t == 0.16
# [Save states] Done!
# Solving for t == 0.01
# [Set dynamic] Done!
# Solving for t == 0.02
# [Set dynamic] Done!
# Solving for t == 0.03
# [Set dynamic] Done!
# Solving for t == 0.04
# [Set dynamic] Done!
# Solving for t == 0.05
# [Set dynamic] Done!
# Solving for t == 0.060000000000000005
# [Set dynamic] Done!
# Solving for t == 0.07
# [Set dynamic] Done!
# Solving for t == 0.08
# [Set dynamic] Done!
# Solving for t == 0.09
# [Set dynamic] Done!
# Solving for t == 0.09999999999999999
# [Set dynamic] Done!
# Solving for t == 0.10999999999999999
# [Set dynamic] Done!
# Solving for t == 0.11999999999999998
# [Set dynamic] Done!
# Solving for t == 0.12999999999999998
# [Set dynamic] Done!
# Solving for t == 0.13999999999999999
# [Set dynamic] Done!
# Solving for t == 0.15
# [Set dynamic] Done!
# Solving for t == 0.16
# [Set dynamic] Done!
# Solving for t == 0.17
# [Set dynamic] Done!
# Optimize...
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =         1089     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.15822D-03    |proj g|=  8.73125D-06
#
# At iterate    1    f=  1.51622D-03    |proj g|=  7.31829D-06
#
# At iterate    2    f=  1.79629D-10    |proj g|=  6.55135D-10
# Done!
# At iterate    3    f=  8.53842D-11    |proj g|=  4.43928D-10
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#  1089      3      6      1     0     0   4.439D-10   8.538D-11
#   F =   8.5384245239560341E-011
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#
# Solving for t == 0.01
# [Save states] Done!
# Solving for t == 0.02
# [Save states] Done!
# Solving for t == 0.03
# [Save states] Done!
# Solving for t == 0.04
# [Save states] Done!
# Solving for t == 0.05
# [Save states] Done!
# Solving for t == 0.060000000000000005
# [Save states] Done!
# Solving for t == 0.07
# [Save states] Done!
# Solving for t == 0.08
# [Save states] Done!
# Solving for t == 0.09
# [Save states] Done!
# Solving for t == 0.09999999999999999
# [Save states] Done!
# Solving for t == 0.10999999999999999
# [Save states] Done!
# Solving for t == 0.11999999999999998
# [Save states] Done!
# Solving for t == 0.12999999999999998
# [Save states] Done!
# Solving for t == 0.13999999999999999
# [Save states] Done!
# Solving for t == 0.15
# [Save states] Done!
# Solving for t == 0.16
# [Save states] Done!
# Solving for t == 0.17
# [Save states] Done!
# Solving for t == 0.01
# [Set dynamic] Done!
# Solving for t == 0.02
# [Set dynamic] Done!
# Solving for t == 0.03
# [Set dynamic] Done!
# Solving for t == 0.04
# [Set dynamic] Done!
# Solving for t == 0.05
# [Set dynamic] Done!
# Solving for t == 0.060000000000000005
# [Set dynamic] Done!
# Solving for t == 0.07
# [Set dynamic] Done!
# Solving for t == 0.08
# [Set dynamic] Done!
# Solving for t == 0.09
# [Set dynamic] Done!
# Solving for t == 0.09999999999999999
# [Set dynamic] Done!
# Solving for t == 0.10999999999999999
# [Set dynamic] Done!
# Solving for t == 0.11999999999999998
# [Set dynamic] Done!
# Solving for t == 0.12999999999999998
# [Set dynamic] Done!
# Solving for t == 0.13999999999999999
# [Set dynamic] Done!
# Solving for t == 0.15
# [Set dynamic] Done!
# Solving for t == 0.16
# [Set dynamic] Done!
# Solving for t == 0.17
# [Set dynamic] Done!
# Solving for t == 0.18000000000000002
# [Set dynamic] Done!
# Optimize...
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =         1089     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.50411D-03    |proj g|=  7.34765D-06
#
# At iterate    1    f=  9.73707D-04    |proj g|=  5.91186D-06
#
# At iterate    2    f=  1.23465D-10    |proj g|=  5.43166D-10
# Done!
# At iterate    3    f=  5.95058D-11    |proj g|=  3.70835D-10
#
# Solving for t == 0.01
# [Save states] Done!
# Solving for t == 0.02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#  1089      3      6      1     0     0   3.708D-10   5.951D-11
#   F =   5.9505772942376110E-011
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# [Save states] Done!
# Solving for t == 0.03
# [Save states] Done!
# Solving for t == 0.04
# [Save states] Done!
# Solving for t == 0.05
# [Save states] Done!
# Solving for t == 0.060000000000000005
# [Save states] Done!
# Solving for t == 0.07
# [Save states] Done!
# Solving for t == 0.08
# [Save states] Done!
# Solving for t == 0.09
# [Save states] Done!
# Solving for t == 0.09999999999999999
# [Save states] Done!
# Solving for t == 0.10999999999999999
# [Save states] Done!
# Solving for t == 0.11999999999999998
# [Save states] Done!
# Solving for t == 0.12999999999999998
# [Save states] Done!
# Solving for t == 0.13999999999999999
# [Save states] Done!
# Solving for t == 0.15
# [Save states] Done!
# Solving for t == 0.16
# [Save states] Done!
# Solving for t == 0.17
# [Save states] Done!
# Solving for t == 0.18000000000000002
# [Save states] Done!
# Solving for t == 0.01
# [Set dynamic] Done!
# Solving for t == 0.02
# [Set dynamic] Done!
# Solving for t == 0.03
# [Set dynamic] Done!
# Solving for t == 0.04
# [Set dynamic] Done!
# Solving for t == 0.05
# [Set dynamic] Done!
# Solving for t == 0.060000000000000005
# [Set dynamic] Done!
# Solving for t == 0.07
# [Set dynamic] Done!
# Solving for t == 0.08
# [Set dynamic] Done!
# Solving for t == 0.09
# [Set dynamic] Done!
# Solving for t == 0.09999999999999999
# [Set dynamic] Done!
# Solving for t == 0.10999999999999999
# [Set dynamic] Done!
# Solving for t == 0.11999999999999998
# [Set dynamic] Done!
# Solving for t == 0.12999999999999998
# [Set dynamic] Done!
# Solving for t == 0.13999999999999999
# [Set dynamic] Done!
# Solving for t == 0.15
# [Set dynamic] Done!
# Solving for t == 0.16
# [Set dynamic] Done!
# Solving for t == 0.17
# [Set dynamic] Done!
# Solving for t == 0.18000000000000002
# [Set dynamic] Done!
# Solving for t == 0.19000000000000003
# [Set dynamic] Done!
# Optimize...
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =         1089     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.04824D-03    |proj g|=  6.17482D-06
#
# At iterate    1    f=  6.12439D-04    |proj g|=  4.71983D-06
#
# At iterate    2    f=  8.50593D-11    |proj g|=  4.50854D-10
# Done!
# At iterate    3    f=  4.14602D-11    |proj g|=  3.09697D-10
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#  1089      3      6      1     0     0   3.097D-10   4.146D-11
#   F =   4.1460215003015635E-011
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#
# Solving for t == 0.01
# [Save states] Done!
# Solving for t == 0.02
# [Save states] Done!
# Solving for t == 0.03
# [Save states] Done!
# Solving for t == 0.04
# [Save states] Done!
# Solving for t == 0.05
# [Save states] Done!
# Solving for t == 0.060000000000000005
# [Save states] Done!
# Solving for t == 0.07
# [Save states] Done!
# Solving for t == 0.08
# [Save states] Done!
# Solving for t == 0.09
# [Save states] Done!
# Solving for t == 0.09999999999999999
# [Save states] Done!
# Solving for t == 0.10999999999999999
# [Save states] Done!
# Solving for t == 0.11999999999999998
# [Save states] Done!
# Solving for t == 0.12999999999999998
# [Save states] Done!
# Solving for t == 0.13999999999999999
# [Save states] Done!
# Solving for t == 0.15
# [Save states] Done!
# Solving for t == 0.16
# [Save states] Done!
# Solving for t == 0.17
# [Save states] Done!
# Solving for t == 0.18000000000000002
# [Save states] Done!
# Solving for t == 0.19000000000000003
# [Save states] Done!
# Solving for t == 0.01
# [Set dynamic] Done!
# Solving for t == 0.02
# [Set dynamic] Done!
# Solving for t == 0.03
# [Set dynamic] Done!
# Solving for t == 0.04
# [Set dynamic] Done!
# Solving for t == 0.05
# [Set dynamic] Done!
# Solving for t == 0.060000000000000005
# [Set dynamic] Done!
# Solving for t == 0.07
# [Set dynamic] Done!
# Solving for t == 0.08
# [Set dynamic] Done!
# Solving for t == 0.09
# [Set dynamic] Done!
# Solving for t == 0.09999999999999999
# [Set dynamic] Done!
# Solving for t == 0.10999999999999999
# [Set dynamic] Done!
# Solving for t == 0.11999999999999998
# [Set dynamic] Done!
# Solving for t == 0.12999999999999998
# [Set dynamic] Done!
# Solving for t == 0.13999999999999999
# [Set dynamic] Done!
# Solving for t == 0.15
# [Set dynamic] Done!
# Solving for t == 0.16
# [Set dynamic] Done!
# Solving for t == 0.17
# [Set dynamic] Done!
# Solving for t == 0.18000000000000002
# [Set dynamic] Done!
# Solving for t == 0.19000000000000003
# [Set dynamic] Done!
# Solving for t == 0.20000000000000004
# [Set dynamic] Done!
# Optimize...
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =         1089     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.30538D-04    |proj g|=  5.18334D-06
#
# At iterate    1    f=  3.74704D-04    |proj g|=  3.71222D-06
#
# At iterate    2    f=  5.87141D-11    |proj g|=  3.74591D-10
# Done!
# At iterate    3    f=  2.88834D-11    |proj g|=  2.58598D-10
#
# Solving for t == 0.01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#  1089      3      6      1     0     0   2.586D-10   2.888D-11
#   F =   2.8883446259767848E-011
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# [Save states] Done!
# Solving for t == 0.02
# [Save states] Done!
# Solving for t == 0.03
# [Save states] Done!
# Solving for t == 0.04
# [Save states] Done!
# Solving for t == 0.05
# [Save states] Done!
# Solving for t == 0.060000000000000005
# [Save states] Done!
# Solving for t == 0.07
# [Save states] Done!
# Solving for t == 0.08
# [Save states] Done!
# Solving for t == 0.09
# [Save states] Done!
# Solving for t == 0.09999999999999999
# [Save states] Done!
# Solving for t == 0.10999999999999999
# [Save states] Done!
# Solving for t == 0.11999999999999998
# [Save states] Done!
# Solving for t == 0.12999999999999998
# [Save states] Done!
# Solving for t == 0.13999999999999999
# [Save states] Done!
# Solving for t == 0.15
# [Save states] Done!
# Solving for t == 0.16
# [Save states] Done!
# Solving for t == 0.17
# [Save states] Done!
# Solving for t == 0.18000000000000002
# [Save states] Done!
# Solving for t == 0.19000000000000003
# [Save states] Done!
# Solving for t == 0.20000000000000004
# [Save states] Done!
# Solving for t == 0.01
# [Set dynamic] Done!
# Solving for t == 0.02
# [Set dynamic] Done!
# Solving for t == 0.03
# [Set dynamic] Done!
# Solving for t == 0.04
# [Set dynamic] Done!
# Solving for t == 0.05
# [Set dynamic] Done!
# Solving for t == 0.060000000000000005
# [Set dynamic] Done!
# Solving for t == 0.07
# [Set dynamic] Done!
# Solving for t == 0.08
# [Set dynamic] Done!
# Solving for t == 0.09
# [Set dynamic] Done!
# Solving for t == 0.09999999999999999
# [Set dynamic] Done!
# Solving for t == 0.10999999999999999
# [Set dynamic] Done!
# Solving for t == 0.11999999999999998
# [Set dynamic] Done!
# Solving for t == 0.12999999999999998
# [Set dynamic] Done!
# Solving for t == 0.13999999999999999
# [Set dynamic] Done!
# Solving for t == 0.15
# [Set dynamic] Done!
# Solving for t == 0.16
# [Set dynamic] Done!
# Solving for t == 0.17
# [Set dynamic] Done!
# Solving for t == 0.18000000000000002
# [Set dynamic] Done!
# Solving for t == 0.19000000000000003
# [Set dynamic] Done!
# Solving for t == 0.20000000000000004
# [Set dynamic] Done!
# Solving for t == 0.21000000000000005
# [Set dynamic] Done!
# Optimize...
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =         1089     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.09125D-04    |proj g|=  4.34699D-06
#
# At iterate    1    f=  2.20743D-04    |proj g|=  2.86234D-06
#
# At iterate    2    f=  4.05940D-11    |proj g|=  3.11476D-10
# Done!
# At iterate    3    f=  2.01208D-11    |proj g|=  2.15909D-10
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
#
# Solving for t == 0.01
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#  1089      3      6      1     0     0   2.159D-10   2.012D-11
#   F =   2.0120758883192617E-011
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# [Save states] Done!
# Solving for t == 0.02
# [Save states] Done!
# Solving for t == 0.03
# [Save states] Done!
# Solving for t == 0.04
# [Save states] Done!
# Solving for t == 0.05
# [Save states] Done!
# Solving for t == 0.060000000000000005
# [Save states] Done!
# Solving for t == 0.07
# [Save states] Done!
# Solving for t == 0.08
# [Save states] Done!
# Solving for t == 0.09
# [Save states] Done!
# Solving for t == 0.09999999999999999
# [Save states] Done!
# Solving for t == 0.10999999999999999
# [Save states] Done!
# Solving for t == 0.11999999999999998
# [Save states] Done!
# Solving for t == 0.12999999999999998
# [Save states] Done!
# Solving for t == 0.13999999999999999
# [Save states] Done!
# Solving for t == 0.15
# [Save states] Done!
# Solving for t == 0.16
# [Save states] Done!
# Solving for t == 0.17
# [Save states] Done!
# Solving for t == 0.18000000000000002
# [Save states] Done!
# Solving for t == 0.19000000000000003
# [Save states] Done!
# Solving for t == 0.20000000000000004
# [Save states] Done!
# Solving for t == 0.21000000000000005
# [Save states] Done!
# Solving for t == 0.01
# [Set dynamic] Done!
# Solving for t == 0.02
# [Set dynamic] Done!
# Solving for t == 0.03
# [Set dynamic] Done!
# Solving for t == 0.04
# [Set dynamic] Done!
# Solving for t == 0.05
# [Set dynamic] Done!
# Solving for t == 0.060000000000000005
# [Set dynamic] Done!
# Solving for t == 0.07
# [Set dynamic] Done!
# Solving for t == 0.08
# [Set dynamic] Done!
# Solving for t == 0.09
# [Set dynamic] Done!
# Solving for t == 0.09999999999999999
# [Set dynamic] Done!
# Solving for t == 0.10999999999999999
# [Set dynamic] Done!
# Solving for t == 0.11999999999999998
# [Set dynamic] Done!
# Solving for t == 0.12999999999999998
# [Set dynamic] Done!
# Solving for t == 0.13999999999999999
# [Set dynamic] Done!
# Solving for t == 0.15
# [Set dynamic] Done!
# Solving for t == 0.16
# [Set dynamic] Done!
# Solving for t == 0.17
# [Set dynamic] Done!
# Solving for t == 0.18000000000000002
# [Set dynamic] Done!
# Solving for t == 0.19000000000000003
# [Set dynamic] Done!
# Solving for t == 0.20000000000000004
# [Set dynamic] Done!
# Solving for t == 0.21000000000000005
# [Set dynamic] Done!
# Solving for t == 0.22000000000000006
# [Set dynamic] Done!
# Optimize...
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =         1089     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.54819D-04    |proj g|=  3.64278D-06
#
# At iterate    1    f=  1.23229D-04    |proj g|=  2.14678D-06
#
# At iterate    2    f=  2.81035D-11    |proj g|=  2.59167D-10
# Done!
# At iterate    3    f=  1.40164D-11    |proj g|=  1.80258D-10
#
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#  1089      3      6      1     0     0   1.803D-10   1.402D-11
#   F =   1.4016420527009666E-011
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Solving for t == 0.01
# [Save states] Done!
# Solving for t == 0.02
# [Save states] Done!
# Solving for t == 0.03
# [Save states] Done!
# Solving for t == 0.04
# [Save states] Done!
# Solving for t == 0.05
# [Save states] Done!
# Solving for t == 0.060000000000000005
# [Save states] Done!
# Solving for t == 0.07
# [Save states] Done!
# Solving for t == 0.08
# [Save states] Done!
# Solving for t == 0.09
# [Save states] Done!
# Solving for t == 0.09999999999999999
# [Save states] Done!
# Solving for t == 0.10999999999999999
# [Save states] Done!
# Solving for t == 0.11999999999999998
# [Save states] Done!
# Solving for t == 0.12999999999999998
# [Save states] Done!
# Solving for t == 0.13999999999999999
# [Save states] Done!
# Solving for t == 0.15
# [Save states] Done!
# Solving for t == 0.16
# [Save states] Done!
# Solving for t == 0.17
# [Save states] Done!
# Solving for t == 0.18000000000000002
# [Save states] Done!
# Solving for t == 0.19000000000000003
# [Save states] Done!
# Solving for t == 0.20000000000000004
# [Save states] Done!
# Solving for t == 0.21000000000000005
# [Save states] Done!
# Solving for t == 0.22000000000000006
# [Save states] Done!
# Solving for t == 0.01
# [Set dynamic] Done!
# Solving for t == 0.02
# [Set dynamic] Done!
# Solving for t == 0.03
# [Set dynamic] Done!
# Solving for t == 0.04
# [Set dynamic] Done!
# Solving for t == 0.05
# [Set dynamic] Done!
# Solving for t == 0.060000000000000005
# [Set dynamic] Done!
# Solving for t == 0.07
# [Set dynamic] Done!
# Solving for t == 0.08
# [Set dynamic] Done!
# Solving for t == 0.09
# [Set dynamic] Done!
# Solving for t == 0.09999999999999999
# [Set dynamic] Done!
# Solving for t == 0.10999999999999999
# [Set dynamic] Done!
# Solving for t == 0.11999999999999998
# [Set dynamic] Done!
# Solving for t == 0.12999999999999998
# [Set dynamic] Done!
# Solving for t == 0.13999999999999999
# [Set dynamic] Done!
# Solving for t == 0.15
# [Set dynamic] Done!
# Solving for t == 0.16
# [Set dynamic] Done!
# Solving for t == 0.17
# [Set dynamic] Done!
# Solving for t == 0.18000000000000002
# [Set dynamic] Done!
# Solving for t == 0.19000000000000003
# [Set dynamic] Done!
# Solving for t == 0.20000000000000004
# [Set dynamic] Done!
# Solving for t == 0.21000000000000005
# [Set dynamic] Done!
# Solving for t == 0.22000000000000006
# [Set dynamic] Done!
# Solving for t == 0.23000000000000007
# [Set dynamic] Done!
# Optimize...
# ...
# [Save states] Done!
# Solving for t == 0.22000000000000006
# [Save states] Done!
# Solving for t == 0.23000000000000007
# [Save states] Done!
# Solving for t == 0.24000000000000007
# [Save states] Done!
# Solving for t == 0.25000000000000006
# [Save states] Done!
# Solving for t == 0.26000000000000006
# [Save states] Done!
# Solving for t == 0.2700000000000001
# [Save states] Done!
# Solving for t == 0.2800000000000001
# [Save states] Done!
# Solving for t == 0.2900000000000001
# [Save states] Done!
# Solving for t == 0.3000000000000001
# [Save states] Done!
# Solving for t == 0.3100000000000001
# [Save states] Done!
# Solving for t == 0.3200000000000001
# [Save states] Done!
# Solving for t == 0.3300000000000001
# [Save states] Done!
# Solving for t == 0.34000000000000014
# [Save states] Done!
# Solving for t == 0.35000000000000014
# [Save states] Done!
# Solving for t == 0.36000000000000015
# [Save states] Done!
# Solving for t == 0.37000000000000016
# [Save states] Done!
# Solving for t == 0.38000000000000017
# [Save states] Done!
# Solving for t == 0.3900000000000002
# [Save states] Done!
# Solving for t == 0.4000000000000002
# [Save states] Done!
# Solving for t == 0.4100000000000002
# [Save states] Done!
# Solving for t == 0.4200000000000002
# [Save states] Done!
# Solving for t == 0.4300000000000002
# [Save states] Done!
# Solving for t == 0.4400000000000002
# [Save states] Done!
# Solving for t == 0.45000000000000023
# [Save states] Done!
# Solving for t == 0.46000000000000024
# [Save states] Done!
# Solving for t == 0.47000000000000025
# [Save states] Done!
# Solving for t == 0.48000000000000026
# [Save states] Done!
# Solving for t == 0.49000000000000027
# [Save states] Done!
# Solving for t == 0.01
# [Set dynamic] Done!
# Solving for t == 0.02
# [Set dynamic] Done!
# Solving for t == 0.03
# [Set dynamic] Done!
# Solving for t == 0.04
# [Set dynamic] Done!
# Solving for t == 0.05
# [Set dynamic] Done!
# Solving for t == 0.060000000000000005
# [Set dynamic] Done!
# Solving for t == 0.07
# [Set dynamic] Done!
# Solving for t == 0.08
# [Set dynamic] Done!
# Solving for t == 0.09
# [Set dynamic] Done!
# Solving for t == 0.09999999999999999
# [Set dynamic] Done!
# Solving for t == 0.10999999999999999
# [Set dynamic] Done!
# Solving for t == 0.11999999999999998
# [Set dynamic] Done!
# Solving for t == 0.12999999999999998
# [Set dynamic] Done!
# Solving for t == 0.13999999999999999
# [Set dynamic] Done!
# Solving for t == 0.15
# [Set dynamic] Done!
# Solving for t == 0.16
# [Set dynamic] Done!
# Solving for t == 0.17
# [Set dynamic] Done!
# Solving for t == 0.18000000000000002
# [Set dynamic] Done!
# Solving for t == 0.19000000000000003
# [Set dynamic] Done!
# Solving for t == 0.20000000000000004
# [Set dynamic] Done!
# Solving for t == 0.21000000000000005
# [Set dynamic] Done!
# Solving for t == 0.22000000000000006
# [Set dynamic] Done!
# Solving for t == 0.23000000000000007
# [Set dynamic] Done!
# Solving for t == 0.24000000000000007
# [Set dynamic] Done!
# Solving for t == 0.25000000000000006
# [Set dynamic] Done!
# Solving for t == 0.26000000000000006
# [Set dynamic] Done!
# Solving for t == 0.2700000000000001
# [Set dynamic] Done!
# Solving for t == 0.2800000000000001
# [Set dynamic] Done!
# Solving for t == 0.2900000000000001
# [Set dynamic] Done!
# Solving for t == 0.3000000000000001
# [Set dynamic] Done!
# Solving for t == 0.3100000000000001
# [Set dynamic] Done!
# Solving for t == 0.3200000000000001
# [Set dynamic] Done!
# Solving for t == 0.3300000000000001
# [Set dynamic] Done!
# Solving for t == 0.34000000000000014
# [Set dynamic] Done!
# Solving for t == 0.35000000000000014
# [Set dynamic] Done!
# Solving for t == 0.36000000000000015
# [Set dynamic] Done!
# Solving for t == 0.37000000000000016
# [Set dynamic] Done!
# Solving for t == 0.38000000000000017
# [Set dynamic] Done!
# Solving for t == 0.3900000000000002
# [Set dynamic] Done!
# Solving for t == 0.4000000000000002
# [Set dynamic] Done!
# Solving for t == 0.4100000000000002
# [Set dynamic] Done!
# Solving for t == 0.4200000000000002
# [Set dynamic] Done!
# Solving for t == 0.4300000000000002
# [Set dynamic] Done!
# Solving for t == 0.4400000000000002
# [Set dynamic] Done!
# Solving for t == 0.45000000000000023
# [Set dynamic] Done!
# Solving for t == 0.46000000000000024
# [Set dynamic] Done!
# Solving for t == 0.47000000000000025
# [Set dynamic] Done!
# Solving for t == 0.48000000000000026
# [Set dynamic] Done!
# Solving for t == 0.49000000000000027
# [Set dynamic] Done!
# Solving for t == 0.5000000000000002
# [Set dynamic] Done!
# Optimize...
# Done!
# Solving for t == 0.01
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =         1089     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
# [Save states] Done!
# Solving for t == 0.02
#
# At iterate    0    f=  1.33007D-21    |proj g|=  1.78921D-15
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#  1089      0      1      0     0     0   1.789D-15   1.330D-21
#   F =   1.3300696466311569E-021
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# [Save states] Done!
# Solving for t == 0.03
# [Save states] Done!
# Solving for t == 0.04
# [Save states] Done!
# Solving for t == 0.05
# [Save states] Done!
# Solving for t == 0.060000000000000005
# [Save states] Done!
# Solving for t == 0.07
# [Save states] Done!
# Solving for t == 0.08
# [Save states] Done!
# Solving for t == 0.09
# [Save states] Done!
# Solving for t == 0.09999999999999999
# [Save states] Done!
# Solving for t == 0.10999999999999999
# [Save states] Done!
# Solving for t == 0.11999999999999998
# [Save states] Done!
# Solving for t == 0.12999999999999998
# [Save states] Done!
# Solving for t == 0.13999999999999999
# [Save states] Done!
# Solving for t == 0.15
# [Save states] Done!
# Solving for t == 0.16
# [Save states] Done!
# Solving for t == 0.17
# [Save states] Done!
# Solving for t == 0.18000000000000002
# [Save states] Done!
# Solving for t == 0.19000000000000003
# [Save states] Done!
# Solving for t == 0.20000000000000004
# [Save states] Done!
# Solving for t == 0.21000000000000005
# [Save states] Done!
# Solving for t == 0.22000000000000006
# [Save states] Done!
# Solving for t == 0.23000000000000007
# [Save states] Done!
# Solving for t == 0.24000000000000007
# [Save states] Done!
# Solving for t == 0.25000000000000006
# [Save states] Done!
# Solving for t == 0.26000000000000006
# [Save states] Done!
# Solving for t == 0.2700000000000001
# [Save states] Done!
# Solving for t == 0.2800000000000001
# [Save states] Done!
# Solving for t == 0.2900000000000001
# [Save states] Done!
# Solving for t == 0.3000000000000001
# [Save states] Done!
# Solving for t == 0.3100000000000001
# [Save states] Done!
# Solving for t == 0.3200000000000001
# [Save states] Done!
# Solving for t == 0.3300000000000001
# [Save states] Done!
# Solving for t == 0.34000000000000014
# [Save states] Done!
# Solving for t == 0.35000000000000014
# [Save states] Done!
# Solving for t == 0.36000000000000015
# [Save states] Done!
# Solving for t == 0.37000000000000016
# [Save states] Done!
# Solving for t == 0.38000000000000017
# [Save states] Done!
# Solving for t == 0.3900000000000002
# [Save states] Done!
# Solving for t == 0.4000000000000002
# [Save states] Done!
# Solving for t == 0.4100000000000002
# [Save states] Done!
# Solving for t == 0.4200000000000002
# [Save states] Done!
# Solving for t == 0.4300000000000002
# [Save states] Done!
# Solving for t == 0.4400000000000002
# [Save states] Done!
# Solving for t == 0.45000000000000023
# [Save states] Done!
# Solving for t == 0.46000000000000024
# [Save states] Done!
# Solving for t == 0.47000000000000025
# [Save states] Done!
# Solving for t == 0.48000000000000026
# [Save states] Done!
# Solving for t == 0.49000000000000027
# [Save states] Done!
# Solving for t == 0.5000000000000002
# [Save states] Done!
# Solving for t == 0.01
# [Set dynamic] Done!
# Optimize...
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =         1089     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.50920D-01    |proj g|=  1.05629D-05
#
# At iterate    1    f=  2.00665D-01    |proj g|=  9.44616D-06
#
# At iterate    2    f=  6.18795D-07    |proj g|=  1.04246D-08
#
# At iterate    3    f=  2.63083D-07    |proj g|=  6.59121D-09
#
# At iterate    4    f=  4.77396D-08    |proj g|=  1.31609D-09
# Done!
#
# At iterate    5    f=  3.32723D-08    |proj g|=  1.09027D-09
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#  1089      5     10      1     0     0   1.090D-09   3.327D-08
#   F =   3.3272271372320239E-008
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Solving for t == 0.01
# [Save states] Done!
# Solving for t == 0.01
# [Set dynamic] Done!
# Solving for t == 0.02
# [Set dynamic] Done!
# Optimize...
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =         1089     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.29610D-02    |proj g|=  7.94162D-06
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:69
#
# File ~/.local/lib/python3.10/site-packages/pyadjoint/tape.py:46, in no_annotations.<locals>.wrapper(*args, **kwargs)
#      43 @wraps(function)
#      44 def wrapper(*args, **kwargs):
#      45     with stop_annotating():
# ---> 46         return function(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/pyadjoint/optimization/optimization.py:252, in minimize(rf, method, scale, **kwargs)
#     248 if algorithm == minimize_scipy_generic:
#     249     # For scipy's generic inteface we need to pass the optimisation method as a parameter.
#     250     kwargs["method"] = method
# --> 252 opt = algorithm(rf_np, **kwargs)
#     254 if len(opt) == 1:
#     255     return opt[0]
#
# File ~/.local/lib/python3.10/site-packages/pyadjoint/optimization/optimization.py:135, in minimize_scipy_generic(rf_np, method, bounds, **kwargs)
#     133     res = scipy_minimize(J, m_global, method=method, bounds=bounds, **kwargs)
#     134 else:
# --> 135     res = scipy_minimize(J, m_global, method=method, **kwargs)
#     137 m = rf_np.set_controls(np.array(res["x"]))
#     138 return m
#
# File /usr/lib/python3/dist-packages/scipy/optimize/_minimize.py:681, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     678     res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     679                              **options)
#     680 elif meth == 'l-bfgs-b':
# --> 681     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     682                            callback=callback, **options)
#     683 elif meth == 'tnc':
#     684     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     685                         **options)
#
# File /usr/lib/python3/dist-packages/scipy/optimize/_lbfgsb_py.py:362, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     356 task_str = task.tobytes()
#     357 if task_str.startswith(b'FG'):
#     358     # The minimization routine wants f and g at the current x.
#     359     # Note that interruptions due to maxfun are postponed
#     360     # until the completion of the current minimization iteration.
#     361     # Overwrite f and g:
# --> 362     f, g = func_and_grad(x)
#     363 elif task_str.startswith(b'NEW_X'):
#     364     # new iteration
#     365     n_iterations += 1
#
# File /usr/lib/python3/dist-packages/scipy/optimize/_differentiable_functions.py:285, in ScalarFunction.fun_and_grad(self, x)
#     283 if not np.array_equal(x, self.x):
#     284     self._update_x_impl(x)
# --> 285 self._update_fun()
#     286 self._update_grad()
#     287 return self.f, self.g
#
# File /usr/lib/python3/dist-packages/scipy/optimize/_differentiable_functions.py:251, in ScalarFunction._update_fun(self)
#     249 def _update_fun(self):
#     250     if not self.f_updated:
# --> 251         self._update_fun_impl()
#     252         self.f_updated = True
#
# File /usr/lib/python3/dist-packages/scipy/optimize/_differentiable_functions.py:155, in ScalarFunction.__init__.<locals>.update_fun()
#     154 def update_fun():
# --> 155     self.f = fun_wrapped(self.x)
#
# File /usr/lib/python3/dist-packages/scipy/optimize/_differentiable_functions.py:137, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     133 self.nfev += 1
#     134 # Send a copy because the user may overwrite it.
#     135 # Overwriting results in undefined behaviour because
#     136 # fun(self.x) will change self.x, with the two no longer linked.
# --> 137 fx = fun(np.copy(x), *args)
#     138 # Make sure the function returns a true scalar
#     139 if not np.isscalar(fx):
#
# File ~/.local/lib/python3.10/site-packages/pyadjoint/reduced_functional_numpy.py:36, in ReducedFunctionalNumPy.__call__(self, m_array)
#      31 """An implementation of the reduced functional evaluation
#      32     that accepts the control values as an array of scalars
#      33
#      34 """
#      35 m_copies = [control.copy_data() for control in self.controls]
# ---> 36 return self.rf.__call__(self.set_local(m_copies, m_array))
#
# File ~/.local/lib/python3.10/site-packages/pyadjoint/tape.py:46, in no_annotations.<locals>.wrapper(*args, **kwargs)
#      43 @wraps(function)
#      44 def wrapper(*args, **kwargs):
#      45     with stop_annotating():
# ---> 46         return function(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/pyadjoint/reduced_functional.py:135, in ReducedFunctional.__call__(self, values)
#     133     with stop_annotating():
#     134         for i in range(len(blocks)):
# --> 135             blocks[i].recompute()
#     137 func_value = self.scale * self.functional.block_variable.checkpoint
#     139 # Call callback
#
# File ~/.local/lib/python3.10/site-packages/pyadjoint/block.py:350, in Block.recompute(self, markings)
#     347 prepared = self.prepare_recompute_component(inputs, relevant_outputs)
#     349 for idx, out in relevant_outputs:
# --> 350     output = self.recompute_component(inputs,
#     351                                       out,
#     352                                       idx,
#     353                                       prepared)
#     354     if output is not None:
#     355         out.checkpoint = output
#
# File ~/.local/lib/python3.10/site-packages/dolfin_adjoint_common/blocks/solving.py:467, in GenericSolveBlock.recompute_component(self, inputs, block_variable, idx, prepared)
#     465 func = prepared[2]
#     466 bcs = prepared[3]
# --> 467 return self._forward_solve(lhs, rhs, func, bcs)
#
# File ~/.local/lib/python3.10/site-packages/dolfin_adjoint_common/blocks/solving.py:453, in GenericSolveBlock._forward_solve(self, lhs, rhs, func, bcs)
#     452 def _forward_solve(self, lhs, rhs, func, bcs):
# --> 453     self.backend.solve(lhs == rhs, func, bcs, *self.forward_args, **self.forward_kwargs)
#     454     return func
#
# File /usr/lib/petsc/lib/python3/dist-packages/dolfin/fem/solving.py:233, in solve(*args, **kwargs)
#     230 # Call variational problem solver if we get an equation (but not a
#     231 # tolerance)
#     232 elif isinstance(args[0], ufl.classes.Equation):
# --> 233     _solve_varproblem(*args, **kwargs)
#     235 # Default case, just call the wrapped C++ solve function
#     236 else:
#     237     if kwargs:
#
# File /usr/lib/petsc/lib/python3/dist-packages/dolfin/fem/solving.py:314, in _solve_varproblem(*args, **kwargs)
#     312 solver = NonlinearVariationalSolver(problem)
#     313 solver.parameters.update(solver_parameters)
# --> 314 solver.solve()
#
# KeyboardInterrupt:
